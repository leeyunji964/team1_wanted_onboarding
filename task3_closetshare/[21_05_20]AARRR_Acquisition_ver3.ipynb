# %% [markdown]
# ## Read Me
#
# **전체적인 코드 작성은 아람님이 진행**<br>
# **아람님 코드를 베이스로 세부 eda 진행함** : Top 5 => Top 10, 요약 <br>
#
# **기존 시각화 코드 모듈화 및 세부 분석만 담당**

# %%
import pandas as pd 
import numpy as np 
#시각화
import matplotlib.pyplot as plt
import seaborn as sns
#경고무시
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'HYGothic-Extra'  # (Windows 용) 한글 출력을 위한 글꼴 설정
plt.rcParams['axes.unicode_minus'] = False    # 문자 - (마이너스) 정상 출력을 위한 코드

#plt.rcParams['font.family'] = 'AppleGothic' # 맥(Mac) 사용자

# %%
df_ori = pd.read_csv('./팀_basline_csv.csv', encoding='utf-8')

# %%
df=df_ori.copy()
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1461   Yves Saint Laurent                 logo point clutch bag pink
# 1462                Prada                        saffiano lux M gray
# 1463             Burberry                basic pattern sweater beige
# 1464               Chanel        graphics pattern sweat-shirts white
# 1465             Burberry                  classic trench coat beige
#
#           USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 0      a161237  2019-12-06  2021-01-15  7days       BA      Y  금요일       주중
# 1     a1140859  2021-01-02  2021-01-15  4days        O      N  금요일       주중
# 2     a1140859  2021-01-02  2021-01-15  4days        B      N  금요일       주중
# 3     a1140859  2021-01-02  2021-01-15  4days        T      N  금요일       주중
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y  금요일       주중
# ...        ...         ...         ...    ...      ...    ...  ...      ...
# 1461   a119721  2019-04-10  2021-03-01  7days       BA      Y  공휴일       휴일
# 1462  a1146069  2021-02-11  2021-03-01  7days       BA      Y  공휴일       휴일
# 1463  a1147848  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1464  a1147788  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 1465   a190054  2020-03-24  2021-03-01  4days        O      Y  공휴일       휴일
#
#       month  How_long
# 0         1       406
# 1         1        13
# 2         1        13
# 3         1        13
# 4         1        14
# ...     ...       ...
# 1461      3       691
# 1462      3        18
# 1463      3         1
# 1464      3         1
# 1465      3       342
#
# [1466 rows x 12 columns]

# %% [markdown]
# >**(1).brandnm: 아이템의 브랜드 이름 컬럼 : 범주형 <br>
# (2).goodsnm : 아이템의 특성을 담은 이름 컬럼 : 범주형 <br>
# (3). USER : 사용자 ID 컬럼 : 범주형 <br>
# (4). reg_date : 사용자 가입일 컬럼 : 날짜형 <br>
# (5). order_date : 아이템 주문일 컬럼 : 날짜형<br>
# (6). p_type : 주문 상품권 종류 5일 7일 : 범주형<br>
# (7). sub_type : 주문 아이템 카테고리 : 범주형 <br>
# (8). add_yn : 사용자의 어플리케이션 사용 여부 : 범주형**

# %% [markdown]
# # Acquisition

# %% [markdown]
# ## 어떻게 많은 고객을 서비스로 유입시킬 수 있을 것인가?
#
# ### 1. 전체 브랜드 중 선호도가 높은 순위

# %%
# print(df.brandnm.unique())
# print('='*30)
print('클로젯쉐어 전체 브랜드 분류 수 :', len(df.brandnm.unique()))
# Out:
# 클로젯쉐어 전체 브랜드 분류 수 : 245

# %%
df.groupby('brandnm').count()
# Out:
#                  goodsnm  USER  reg_date  order_date  p_type  sub_type  \
# brandnm
# & Other Stories        8     8         8           8       8         8
# A BY A                 1     1         1           1       1         1
# A.P.C.                 3     3         3           3       3         3
# ACNE STUDIOS           4     4         4           4       4         4
# Adidas                 1     1         1           1       1         1
# ...                  ...   ...       ...         ...     ...       ...
# Zooc                   2     2         2           2       2         2
# cecilie bahnsen        1     1         1           1       1         1
# khrisjoy               1     1         1           1       1         1
# roajeu                 1     1         1           1       1         1
# thom browne            1     1         1           1       1         1
#
#                  app_yn  days  day_type  month  How_long
# brandnm
# & Other Stories       8     8         8      8         8
# A BY A                1     1         1      1         1
# A.P.C.                3     3         3      3         3
# ACNE STUDIOS          4     4         4      4         4
# Adidas                1     1         1      1         1
# ...                 ...   ...       ...    ...       ...
# Zooc                  2     2         2      2         2
# cecilie bahnsen       1     1         1      1         1
# khrisjoy              1     1         1      1         1
# roajeu                1     1         1      1         1
# thom browne           1     1         1      1         1
#
# [245 rows x 11 columns]

# %%
# 구매가 많은 상위 10개 브랜드
df.brandnm.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gucci                 230
# Chanel                 90
# Saint Laurent          86
# Louis Vuitton          79
# Prada                  58
# Burberry               53
# Yves Saint Laurent     38
# Thom Browne            33
# Mixed                  29
# Celine                 28
# Name: brandnm, dtype: int64

# %%
plt.rcParams['font.family'] = 'HYGothic-Extra'

best_br = df.brandnm.value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(25,8))
sns.barplot(best_br.index, best_br.values, palette='dark')
plt.grid()
plt.title('상위 10개 브랜드', fontsize=18)
plt.ylabel('판매량(count)', fontsize=16)
plt.xlabel('브랜드', fontsize=16)
plt.show()

# %%
# 상위 10개 브랜드 sub_type 분포
# br = list(df.brandnm.value_counts().sort_values(ascending=False).head(30))
br = list(df.brandnm.value_counts().sort_values(ascending=False).head(10).index)

f, ax = plt.subplots(5,2 , figsize = (20,30))
axx = ax.flatten()
plt.rcParams['font.family'] = 'HYGothic-Extra'

for axx2, j in zip(axx, br) :
    sns.set_style('whitegrid')
    plt.subplot(axx2)
    b_ca = df[df['brandnm'] == j]
    sns.countplot(data = b_ca, x= 'sub_type', hue='p_type', palette='Accent', ax= axx2)
    plt.title(j, fontsize = 18)

# %% [markdown]
# ### - Top1 : Gucci 데이터만 따로 보기

# %%
# gucci 데이터만 따로 보기
gucci = df.query('brandnm == "Gucci"')[:]
gucci
# Out:
#      brandnm                              goodsnm      USER    reg_date  \
# 0      Gucci   flower dionysus shoulder bag beige   a161237  2019-12-06
# 8      Gucci                   dionysus cross bag  a1143028  2021-01-14
# 16     Gucci  microssima mini cross body bag pink  a1142921  2021-01-14
# 34     Gucci       padlock GG canvas shoulder bag   a143862  2019-09-29
# 36     Gucci                 flap cross bag black  a1141099  2021-01-04
# ...      ...                                  ...       ...         ...
# 1445   Gucci              super mini sylvie white  a1144433  2021-01-25
# 1447   Gucci     vintage web GG two way bag brown  a1117218  2020-08-30
# 1451   Gucci     sylvie mini chain ribbon bag red  a1147961  2021-03-01
# 1452   Gucci      microssima emily mini bag black  a1147942  2021-03-01
# 1454   Gucci  marmont gg logo quilted bag Black 2   a177034  2020-01-23
#
#       order_date p_type sub_type app_yn days day_type  month  How_long
# 0     2021-01-15  7days       BA      Y  금요일       주중      1       406
# 8     2021-01-15  4days       BA      Y  금요일       주중      1         1
# 16    2021-01-14  4days       BA      Y  목요일       주중      1         0
# 34    2021-01-14  4days       BA      Y  목요일       주중      1       473
# 36    2021-01-13  4days       BA      Y  수요일       주중      1         9
# ...          ...    ...      ...    ...  ...      ...    ...       ...
# 1445  2021-03-02  7days       BA      Y  화요일       주중      3        36
# 1447  2021-03-02  7days       BA      Y  화요일       주중      3       184
# 1451  2021-03-01  4days       BA      Y  공휴일       휴일      3         0
# 1452  2021-03-01  7days       BA      Y  공휴일       휴일      3         0
# 1454  2021-03-01  4days       BA      Y  공휴일       휴일      3       403
#
# [230 rows x 12 columns]

# %%
def show_brands(brand):
    f, ax  = plt.subplots(2,2,figsize=(15,10))
    plt.rcParams['font.family'] = 'HYGothic-Extra'


    plt.subplot(221)
    sns.countplot(data=brand, x='days')
    plt.title('요일별 주문 건수')

    plt.subplot(222)
    sns.countplot(data=brand, x='p_type')
    plt.title('p_type별 주문건')

    plt.subplot(223)
    sns.countplot(data=brand, x='sub_type')
    plt.title('sub_type별 주문건')

    plt.subplot(224)
    sns.countplot(data=brand, x='days', hue='app_yn')
    plt.title('요일별 앱 유입여부')

    plt.suptitle(str(brand['brandnm'][0]) + ' 상품 이용객 분류',fontsize=30, fontweight = 'bold')
    plt.show()

# %%
show_brands(gucci)

# %% [markdown]
# ### - Top2 : Chanel 데이터만 따로 보기

# %%
Chanel = df.query('brandnm == "Chanel"')[:]
Chanel.reset_index(inplace=True)
Chanel
# Out:
#     index brandnm                                            goodsnm  \
# 0      28  Chanel  brooch stripe pattern turtle neck turtleneck navy
# 1      58  Chanel            pocket tweed pattern cashmere coat pink
# 2      98  Chanel                   classic chain shoulder bag black
# 3     103  Chanel      pocket basic pattern wool fullzip-jacket grey
# 4     135  Chanel          pocket graphics pattern zipup-jumper navy
# ..    ...     ...                                                ...
# 85   1450  Chanel              stripe pattern pointed cardigan multi
# 86   1453  Chanel                            boy chanel clutch black
# 87   1455  Chanel                  brooch check pattern jacket cream
# 88   1456  Chanel            pocket tweed pattern cashmere coat pink
# 89   1464  Chanel                graphics pattern sweat-shirts white
#
#         USER    reg_date  order_date p_type sub_type app_yn days day_type  \
# 0   a1136028  2020-12-09  2021-01-14  4days        T      Y  목요일       주중
# 1   a1138513  2020-12-20  2021-01-11  4days        O      Y  월요일       주중
# 2   a1141379  2021-01-06  2021-01-06  7days       BA      Y  수요일       주중
# 3   a1141288  2021-01-05  2021-01-06  4days        O      Y  수요일       주중
# 4   a1112031  2020-08-15  2021-01-01  7days        O      N  공휴일       휴일
# ..       ...         ...         ...    ...      ...    ...  ...      ...
# 85  a1147961  2021-03-01  2021-03-01  4days        O      Y  공휴일       휴일
# 86  a1147960  2021-03-01  2021-03-01  7days       BA      Y  공휴일       휴일
# 87  a1146108  2021-02-11  2021-03-01  7days        O      Y  공휴일       휴일
# 88  a1147959  2021-03-01  2021-03-01  7days        O      N  공휴일       휴일
# 89  a1147788  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
#
#     month  How_long
# 0       1        36
# 1       1        22
# 2       1         0
# 3       1         1
# 4       1       139
# ..    ...       ...
# 85      3         0
# 86      3         0
# 87      3        18
# 88      3         0
# 89      3         1
#
# [90 rows x 13 columns]

# %%
show_brands(Chanel)

# %% [markdown]
# ### - Top3 : Saint Laurent 데이터만 따로 보기

# %%
S_Laurent = df.query('brandnm == "Saint Laurent"')[:]
S_Laurent.reset_index(inplace=True)
S_Laurent
# Out:
#     index        brandnm                            goodsnm      USER  \
# 0      45  Saint Laurent    chevron quilted cross bag black  a1140871
# 1      51  Saint Laurent    chevron quilted cross bag black  a1141925
# 2      56  Saint Laurent        mini sunset chain bag black  a1142471
# 3      67  Saint Laurent  button basic pattern blazer black  a1140758
# 4     115  Saint Laurent      quilted calfskin shoulder bag  a1139320
# ..    ...            ...                                ...       ...
# 81   1311  Saint Laurent    chevron quilted cross bag black  a1135400
# 82   1320  Saint Laurent  monogram mini universal bag black  a1148747
# 83   1357  Saint Laurent    chevron quilted cross bag black  a1148129
# 84   1377  Saint Laurent      quilted calfskin shoulder bag  a1148237
# 85   1383  Saint Laurent    chevron quilted cross bag black  a1148220
#
#       reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 0   2021-01-02  2021-01-13  4days       BA      Y  수요일       주중      1
# 1   2021-01-09  2021-01-12  4days       BA      Y  화요일       주중      1
# 2   2021-01-12  2021-01-12  7days       BA      Y  화요일       주중      1
# 3   2021-01-01  2021-01-10  7days        O      Y  일요일       휴일      1
# 4   2020-12-22  2021-01-05  7days       BA      Y  화요일       주중      1
# ..         ...         ...    ...      ...    ...  ...      ...    ...
# 81  2020-12-05  2021-03-09  4days       BA      Y  화요일       주중      3
# 82  2021-03-09  2021-03-09  7days       BA      Y  화요일       주중      3
# 83  2021-03-03  2021-03-06  7days       BA      N  토요일       휴일      3
# 84  2021-03-04  2021-03-04  4days       BA      N  목요일       주중      3
# 85  2021-03-04  2021-03-04  7days       BA      Y  목요일       주중      3
#
#     How_long
# 0         11
# 1          3
# 2          0
# 3          9
# 4         14
# ..       ...
# 81        94
# 82         0
# 83         3
# 84         0
# 85         0
#
# [86 rows x 13 columns]

# %%
show_brands(S_Laurent)

# %% [markdown]
# ### - Top4 : Louis Vuitton 데이터만 따로 보기

# %%
Louis_Vuitton = df.query('brandnm == "Louis Vuitton"')[:]
Louis_Vuitton.reset_index(inplace=True)
Louis_Vuitton
# Out:
#     index        brandnm                                   goodsnm      USER  \
# 0      10  Louis Vuitton  twist monogram patent shoulder bag black  a1140216
# 1      44  Louis Vuitton               monogram shoulder bag black   a164734
# 2      73  Louis Vuitton                alma epi pm tote bag black  a1141816
# 3      91  Louis Vuitton                     monogram clutch brown  a1141530
# 4     144  Louis Vuitton                 logo chain tote bag black  a1144704
# ..    ...            ...                                       ...       ...
# 74   1325  Louis Vuitton         verni mini clutch chain bag brown  a1138484
# 75   1332  Louis Vuitton                     monogram clutch brown  a1148708
# 76   1384  Louis Vuitton       galliera gm Shoulder hobo Bag white  a1148221
# 77   1417  Louis Vuitton         Pochette trunk vertical black bag  a1148115
# 78   1426  Louis Vuitton                monogram two way bag brown  a1148075
#
#       reg_date  order_date p_type sub_type app_yn days day_type  month  \
# 0   2020-12-28  2021-01-15  7days       BA      Y  금요일       주중      1
# 1   2019-12-13  2021-01-13  4days       BA      Y  수요일       주중      1
# 2   2021-01-09  2021-01-09  7days       BA      Y  토요일       휴일      1
# 3   2021-01-07  2021-01-07  7days       BA      Y  목요일       주중      1
# 4   2021-01-27  2021-01-30  4days       BA      Y  토요일       휴일      1
# ..         ...         ...    ...      ...    ...  ...      ...    ...
# 74  2020-12-20  2021-03-09  7days       BA      Y  화요일       주중      3
# 75  2021-03-09  2021-03-09  4days       BA      Y  화요일       주중      3
# 76  2021-03-04  2021-03-04  7days       BA      Y  목요일       주중      3
# 77  2021-03-03  2021-03-03  4days       BA      Y  수요일       주중      3
# 78  2021-03-03  2021-03-03  7days       BA      Y  수요일       주중      3
#
#     How_long
# 0         18
# 1        397
# 2          0
# 3          0
# 4          3
# ..       ...
# 74        79
# 75         0
# 76         0
# 77         0
# 78         0
#
# [79 rows x 13 columns]

# %%
show_brands(Louis_Vuitton)

# %% [markdown]
# ### - Top5 : Prada 데이터만 따로 보기

# %%
Prada = df.query('brandnm == "Prada"')[:]
Prada.reset_index(inplace=True)
Prada
# Out:
#     index brandnm                                            goodsnm  \
# 0       5   Prada                            ruffle detail long coat
# 1      12   Prada                        color fur detail coat black
# 2      13   Prada                  zipper detail cape padding jumper
# 3      15   Prada                                logo hobo bag black
# 4      30   Prada                       quilted cross body bag black
# 5      37   Prada                    single button modern coat black
# 6      48   Prada                       collar point long coat multi
# 7      53   Prada  button check pattern wool singlebreasted-jacke...
# 8     123   Prada                          padding two way bag black
# 9     171   Prada                                logo hobo bag black
# 10    176   Prada                   fur detail slim line single coat
# 11    225   Prada                     gradation color padding jumper
# 12    235   Prada                    gold logo crossbody bag hotpink
# 13    262   Prada               small logo classic two way bag black
# 14    271   Prada                                saffiano lux M gray
# 15    306   Prada                    button basic pattern coat black
# 16    310   Prada                            striped strap cross bag
# 17    327   Prada          pocket basic pattern padding-outer orange
# 18    348   Prada                   quilted chain shoulder bag black
# 19    370   Prada                           check pattern lined vest
# 20    375   Prada                         high neck robe jumper gray
# 21    407   Prada                             saffiano mini bag blue
# 22    413   Prada                     saffiano cross chain bag black
# 23    414   Prada                  shirring detail two way bag black
# 24    443   Prada                saffiano leather mini crossbody bag
# 25    470   Prada                      logo point suede bag burgundy
# 26    551   Prada                      color strap shoulder bag navy
# 27    611   Prada                  zipper detail cape padding jumper
# 28    612   Prada                            striped strap cross bag
# 29    631   Prada                     gradation color padding jumper
# 30    634   Prada                     top handle corssbody bag black
# 34      2         2
# 35      2         1
# 36      2         2
# 37      2         0
# 38      2         0
# 39      2       182
# 40      2        58
# 41      2         2
# 42      2         1
# 43      3         1
# 44      3         0
# 45      3        51
# 46      3         3
# 47      3         2
# 48      3         0
# 49      3        26
# 50      3         3
# 51      3         0
# 52      3       133
# 53      3         3
# 54      3         9
# 55      3       410
# 56      3         1
# 57      3        18

# %%
show_brands(Prada)

# %% [markdown]
# ### - Top6 : Burberry 데이터만 따로보기

# %%
Burberry = df.query('brandnm == "Burberry"')[:]
Burberry.reset_index(inplace=True)
Burberry
# Out:
#     index   brandnm                                            goodsnm  \
# 0      26  Burberry                           shawl collar double coat
# 1     120  Burberry                 belt basic pattern trench-coat red
# 2     145  Burberry                     button basic pattern top black
# 3     148  Burberry                   high neck design long coat brown
# 4     182  Burberry                          tb leather belt bag black
# 5     209  Burberry               button basic pattern wool coat brown
# 6     221  Burberry                            classic cross bag black
# 7     234  Burberry        button Quilting pattern padding-outer beige
# 8     257  Burberry             button basic pattern wool jacket black
# 9     270  Burberry               belt check pattern trench-coat beige
# 10    314  Burberry                        belt long trench coat black
# 11    365  Burberry        pocket Quilting pattern padding-outer khaki
# 12    392  Burberry  printing lettering pattern singlebreasted-coat...
# 13    393  Burberry                        vintage check lettering bag
# 14    457  Burberry        button Quilting pattern padding-outer beige
# 15    508  Burberry                  button basic pattern jacket black
# 16    519  Burberry               belt basic pattern trench-coat beige
# 17    533  Burberry             belt basic pattern padding-outer black
# 18    549  Burberry                       classic logo cross bag brown
# 19    568  Burberry          vintage check and leather cross bag black
# 20    625  Burberry                        stripe pattern blouse brown
# 21    714  Burberry                   button check pattern dress brown
# 22    723  Burberry             embroidery basic pattern sweater ivory
# 23    797  Burberry          vintage check and leather cross bag black
# 24    828  Burberry            button check pattern H-Line dress multi
# 25    842  Burberry                     button basic pattern top black
# 26    854  Burberry            button basic pattern wool cardigan grey
# 27    916  Burberry               belt basic pattern trench-coat beige
# 28    929  Burberry                        python cross body bag black
# 29    934  Burberry               belt check pattern trench-coat beige
# 30    972  Burberry                      hook detail trench coat beige
# 31    992  Burberry  printing lettering pattern singlebreasted-coat...
# 32   1018  Burberry                       belt basic pattern coat pink
# 33   1074  Burberry                   basic pattern wool sweater black
# 34   1131  Burberry                 belt basic pattern trench-coat red
# 35   1135  Burberry          belt basic pattern wool trench-coat khaki
# 36   1138  Burberry              pocket basic pattern trench-coat navy
# 37   1188  Burberry                   lettering pattern t-shirts white
# 38   1213  Burberry                          classic trench coat beige
# 39   1225  Burberry                   basic pattern sweat-shirts ivory
# 40   1265  Burberry                    basic pattern wool sweater navy
# 41   1280  Burberry                     button basic pattern top black
# 42   1284  Burberry                         vintage check shoulder bag
# 43   1292  Burberry               belt basic pattern trench-coat beige
# 44   1361  Burberry                        check pattern flap tote bag
# 45   1388  Burberry                       belt basic pattern coat pink
# 46   1407  Burberry                     check pattern kilt-skirt brown
# 47   1408  Burberry               belt check pattern trench-coat beige
# 48   1448  Burberry                 zipper detail pointed jacket beige
# 49   1449  Burberry            button basic pattern wool cardigan grey
# 50   1458  Burberry                     check mackenzie cross bag pink
# 39  a1149457  2021-03-15  2021-03-15  7days        T      Y  월요일       주중
# 40  a1149010  2021-03-11  2021-03-11  4days        T      Y  목요일       주중
# 41  a1127412  2020-10-28  2021-03-10  4days        T      Y  수요일       주중
# 42  a1148134  2021-03-03  2021-03-10  4days       BA      Y  수요일       주중
# 43   a187924  2020-03-11  2021-03-10  7days        O      N  수요일       주중
# 44  a1147456  2021-02-24  2021-03-06  7days       BA      Y  토요일       휴일
# 45  a1148086  2021-03-03  2021-03-04  4days        O      Y  목요일       주중
# 46  a1144910  2021-01-29  2021-03-03  4days        B      N  수요일       주중
# 47  a1144910  2021-01-29  2021-03-03  4days        O      N  수요일       주중
# 48   a163815  2019-12-12  2021-03-01  7days        O      Y  공휴일       휴일
# 49   a163815  2019-12-12  2021-03-01  7days        O      Y  공휴일       휴일
# 50  a1147938  2021-03-01  2021-03-01  7days       BA      Y  공휴일       휴일
# 51  a1147848  2021-02-28  2021-03-01  7days        T      Y  공휴일       휴일
# 52   a190054  2020-03-24  2021-03-01  4days        O      Y  공휴일       휴일
#
#     month  How_long
# 0       1         1
# 1       1       112
# 2       1         3
# 3       1       328
# 4       1         3
# 5       1         6
# 6       1         1
# 7       1       402
# 8       1         4
# 9       1         8
# 10      1       705
# 11      1       586
# 12      2         0
# 13      2         0
# 14      2         0
# 15      2         3
# 16      2         3
# 17      2        44
# 18      2       186
# 19      2         0
# 20      2        48
# 21      2       107
# 22      2        88
# 23      2         6
# 24      3         3
# 25      3         5
# 26      3         0
# 27      3       472
# 28      3         0
# 29      3       462
# 30      3         8
# 31      3         0
# 32      3         0
# 33      3         0
# 34      3       534
# 35      3       468
# 36      3       219
# 37      3       101
# 38      3         9
# 39      3         0
# 40      3         0
# 41      3       133
# 42      3         7
# 43      3       364
# 44      3        10
# 45      3         1
# 46      3        33
# 47      3        33
# 48      3       445
# 49      3       445
# 50      3         0
# 51      3         1
# 52      3       342

# %%
show_brands(Burberry)

# %% [markdown]
# ### - Top7 : Yves Saint Laurent 데이터만 따로보기

# %%
Laurent = df.query('brandnm == "Yves Saint Laurent"')[:]
Laurent.reset_index(inplace=True)

# %%
show_brands(Laurent)

# %% [markdown]
# ### - Top8 : Thom Browne 데이터만 따로보기

# %%
Thome_Browne = df.query('brandnm == "Thom Browne"')[:]
Thome_Browne.reset_index(inplace=True)

# %%
show_brands(Thome_Browne)

# %% [markdown]
# ### - Top9 : Mixed 데이터만 따로보기

# %%
Mixed = df.query('brandnm == "Mixed"')[:]
Mixed.reset_index(inplace=True)

# %%
show_brands(Mixed)

# %% [markdown]
# ### - Top10 : Celine 데이터만 따로보기

# %%
Celine = df.query('brandnm == "Celine"')[:]
Celine.reset_index(inplace=True)

# %%
show_brands(Celine)

# %% [markdown]
# ### Top 10 요약

# %% [markdown]
# **1. 요일별 주문 건수**
# - Gucci : 화-수-목-월-금/일-토-공휴일
# - Chanel : 수-목-화-월-일/공휴일 - 토
# - Saint Laurent : 수-목-화-월/금-토-일-공휴일
# - Louis Vuitton : 화-수-목-금-월/토-일-공휴일
# - Prada : 수/목-월/화-금-일-공휴일
# - Burberry : 수-목-금-월-공휴일-화-토/일
# - Yves Saint Laurent : 수/금-화-월/목/일-토-공휴일
# - Thom Browne : 화-목-수/금-월-공휴일-토
# - Mixed : 목-화-수/금-월-토/일
# - Celine : 수-화-금-목-월-토/일
#
# **2. p_type건 주문건**
# - 4 < 7 : Chanel, Louis Vuitton, Celine
# - 4 > 7 : Saint Laurent, Prada, Burberry, Yves Saint Laurent, Thom Browne, Mixed
# - 4 = 7 : Gucci
#
#
# **3. sub_type별 주문건**
# - Gucci : BA >>> T > D > O/B
# - Chanel : BA >>> O > T
# - Saint Laurent :  BA >>>>>>> 0/T
# - Louis Vuitton : BA >>>>>>>>>>> O
# - Prada : BA >>> O >> T
# - Burberry : O >> T/BA > D > B
# - Yves Saint Laurent : BA >>>>>>>> T > B/O
# - Thom Browne : T > O >> B
# - Mixed : TP(Only)
# - Celine : BA >>> O > T
#
# **4. 요일별 앱 유입 여부(Yes)**
# - Gucci : 화/수-목-월-금-일-토-공휴일
# - Chanel : 수-목-화-월-일-금-공휴일-토
# - Saint Laurent : 수-화-월/목/금-토-일-공휴일
# - Louis Vuitton : 화/수-목-월/금/토-일-공휴일
# - Prada : 목-수-월-화-금-일-공
# - Burberry : 수-목-금-월-공휴일-화-일-토
# - Yves Saint Laurent : 수/금-월/화/일-목-토-공휴일
# - Thom Browne : 화-수/목/금-월-토/공휴일
# - Mixed : 목-수-월-화-토/일-금
# - Celine : 수-화-금-월/목-토/일

# %% [markdown]
# ## 2. 전체 아이템 중 선호도가 높은 순위 기준

# %%
# 개별 아이템별 선호도 상품 분석 

best_item = list(df.goodsnm.value_counts().head(11).index)
cnt = list(df.goodsnm.value_counts().head(11).values)

# %%
for i in range(len(best_item)):
    bname = df[df.goodsnm == best_item[i]]['brandnm'].unique()
    print(bname, ':', best_item[i], '주문수량', cnt[i])
# Out:
# ['Saint Laurent'] : chevron quilted cross bag black 주문수량 23
# ['Chanel'] : classic clutch black 주문수량 12
# ['Chanel'] : boy chanel clutch black 주문수량 11
# ['Gucci'] : padlock GG canvas shoulder bag 주문수량 9
# ['Gucci'] : dionysus shoulder bag beige 주문수량 8
# ['Louis Vuitton'] : epi tote bag black 주문수량 8
# ['Saint Laurent'] : mini sunset chain bag black 주문수량 8
# ['Gucci'] : dionysus cross bag beige 주문수량 7
# ['Gucci'] : flap cross bag black 주문수량 7
# ['Louis Vuitton'] : monogram clutch brown 주문수량 7
# ['Saint Laurent' 'Chanel'] : quilted shoulder bag black 주문수량 7

# %%
# 월별/요일별/ 개별 아이템 사진첨부

# %% [markdown]
# # 상위 아이템 분석

# %% [markdown]
# - ['Saint Laurent'] : chevron quilted cross bag black 주문수량 23
# - ['Chanel'] : classic clutch black 주문수량 12
# - ['Chanel'] : boy chanel clutch black 주문수량 11

# %%
cross_bag = df.query('goodsnm == "chevron quilted cross bag black"')
cluth_black = df.query('goodsnm == "classic clutch black"')
chanel_cluth = df.query('goodsnm == "boy chanel clutch black"')

# %% [markdown]
# ## 월별 count

# %%
def high_items(x):
    plt.figure(figsize=(20,7))
    plt.rcParams['font.family'] = 'HYGothic-Extra'

    plt.subplot(131)
    sns.countplot(data=cross_bag, x=x)
    plt.title('Saint Laurent - chevron quilted cross bag black 월별 count')

    plt.subplot(132)
    sns.countplot(data=cluth_black, x=x)
    plt.title('Chanel - classic cluth black 월별 count')

    plt.subplot(133)
    sns.countplot(data=chanel_cluth, x=x)
    plt.title('Chanel - boy chanel cluth black 월별 count')

    plt.suptitle('상위 제품 3개 월별 count',fontsize=30, fontweight = 'bold')
    plt.show()

# %%
high_items('month')

# %% [markdown]
# - 생로랑은 1 = 2 < 3월
# - 샤넬은 1월달 데이터가 없음. 두 제품 모두 2 < 3
#     - 그렇다면 chanel 제품들은 2월에 업데이트 된 상품이 아닐까? 라는 추측을 해봄

# %% [markdown]
# ## 요일별 count

# %%
high_items('days')

# %% [markdown]
# ## 주중/휴일별 아이템 분석

# %%
high_items('day_type')

# %% [markdown]
# ## 가입 후 기간별 아이템 분석

# %%
high_items('How_long')

# %% [markdown]
# - 대부분이 가입 당일 혹은 1일 이내에 빌림

# %%
print(cluth_black[cluth_black['How_long'] > 1]['order_date'], '\n')
print(cluth_black[cluth_black['How_long'] > 1]['order_date'].min())
# Out:
# 464     2021-02-24
# 649     2021-02-13
# 741     2021-02-04
# 839     2021-03-31
# 973     2021-03-25
# 978     2021-03-24
# 1309    2021-03-09
# 1333    2021-03-09
# Name: order_date, dtype: object
#
# 2021-02-04

# %%
print(chanel_cluth[chanel_cluth['How_long'] > 1]['order_date'], '\n')
print(chanel_cluth[chanel_cluth['How_long'] > 1]['order_date'].min())
# Out:
# 750     2021-02-04
# 1192    2021-03-16
# Name: order_date, dtype: object
#
# 2021-02-04

# %% [markdown]
# ### idea?

# %% [markdown]
# - 아까 위에서 chanel 제품들은 2월에 들어온 상품이 아닐까? 란 가정을 세웠는데,<br> 가입한 지 꽤 된 유저들의 구매일자를 확인해보니 모두 2,3월임 이 중 가장 빠른 결제일이 **2월 4일**
# - 샤넬의 두 번째 제품도 마찬가지임. 가장 빠른 결제일이 **2월 4일**
# - **상위 제품 2,3위인 샤넬의 제품은 2월에 업데이트 된 것으로 판단**
#     - 신상에 대한 욕구 有?
#         - 이게 진짜 시즌 신상인지, 아니면 클로젯 셰어 내에서의 신상일지 판단 확인 필요
#         - 클로젯 셰어에서 검색한 결과, 동일 제품인데 new 라벨이 붙어있는 제품 존재. **클로젯 셰어 내부에서의 신상(재고가 추가됨)으로 판단**
#
# - 상위 3개 제품의 디자인은 모두 **베이직한 디자인**임. 게다가 모두 **검정색**
#     - *클로젯 셰어 인스타그램에 베스트 셀러 bags들을 모아놨는데 ..... 음.. 어떻게 연결지을 수 있을까요*
#     - 클로젯 셰어 인스타그램 주소 : https://www.instagram.com/closetshare_kr/
#         - 게시글 보려면 로그인 필수

# %% [markdown]
# ## 일회권 별 count

# %%
high_items('p_type')

# %% [markdown]
# - 생로랑과 샤넬 classicd cluth black 제품은 4days가 많고, boy chanel cluth black은 7days가 많음
#     - 같은 브랜드의 아이템인데 왜 차이가 있을까?
#         - chanel classic clutch black : 39000/49000원 多 (15개 존재)
#         - boy chanel cluth black : 49000/59000 (1개 존재)
#            - 가격은 비슷한데? 재고 수의 차이 때문일까?
